# %%
import pandas as pd
df_educacion=pd.read_excel("DATA-EDUCACION.xls")

df_educacion
# Out:
#            Data Source Indicadores del desarrollo mundial  \
# 0    Last Updated Date                2023-09-19 00:00:00
# 1                  NaN                                NaN
# 2         Country Name                       Country Code
# 3                Aruba                                ABW
# 4                  NaN                                AFE
# ..                 ...                                ...
# 264             Kosovo                                XKX
# 265    Yemen, Rep. del                                YEM
# 266          Sudáfrica                                ZAF
# 267             Zambia                                ZMB
# 268           Zimbabwe                                ZWE
#
#                                             Unnamed: 2         Unnamed: 3  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# ...

# %%
# mostrar filas solo de alemania

df_alemania = df_educacion[df_educacion['Data Source'] == 'Alemania']

df_alemania
# Out:
#    Data Source Indicadores del desarrollo mundial  \
# 58    Alemania                                DEU
#
#                                            Unnamed: 2         Unnamed: 3  \
# 58  Tasa de finalización de la educación de nivel ...  SE.PRM.CMPT.FE.ZS
#
#     Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 58         NaN         NaN         NaN         NaN         NaN         NaN
#
#     ...  Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# 58  ...    98.309227    97.242844    98.986351     98.30188    99.117043
#
#     Unnamed: 62  Unnamed: 63  Unnamed: 64  Unnamed: 65  Unnamed: 66
# 58   101.587769    99.844048    99.388832          NaN          NaN
#
# [1 rows x 67 columns]
