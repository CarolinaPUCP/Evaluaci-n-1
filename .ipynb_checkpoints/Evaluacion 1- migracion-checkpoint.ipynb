# %%
import pandas as pd

df_migracion=pd.read_excel("DATA-MIGRACION.xls")

df_migracion
# Out:
#            Data Source Indicadores del desarrollo mundial      Unnamed: 2  \
# 0    Last Updated Date                2023-09-19 00:00:00             NaN
# 1                  NaN                                NaN             NaN
# 2         Country Name                       Country Code  Indicator Name
# 3                Aruba                                ABW  Migración neta
# 4                  NaN                                AFE  Migración neta
# ..                 ...                                ...             ...
# 264             Kosovo                                XKX  Migración neta
# 265    Yemen, Rep. del                                YEM  Migración neta
# 266          Sudáfrica                                ZAF  Migración neta
# 267             Zambia                                ZMB  Migración neta
# 268           Zimbabwe                                ZWE  Migración neta
#
#          Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# ...

# %%
# mostrar filas solo de alemania

df_alemania = df_migracion[df_migracion['Data Source'] == 'Alemania']

df_alemania
# Out:
#    Data Source Indicadores del desarrollo mundial      Unnamed: 2  \
# 58    Alemania                                DEU  Migración neta
#
#      Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 58  SM.POP.NETM    100380.0    121350.0    137698.0    152170.0    162533.0
#
#     Unnamed: 9  ...  Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  \
# 58    170903.0  ...     342555.0     369027.0     397921.0     432017.0
#
#     Unnamed: 61  Unnamed: 62  Unnamed: 63  Unnamed: 64  Unnamed: 65  \
# 58     430803.0     392587.0     360560.0     334055.0     312735.0
#
#     Unnamed: 66
# 58          NaN
#
# [1 rows x 67 columns]
