# %%
import pandas as pd

df_carbon=pd.read_excel("DATA-CARBON.xlsx")

df_carbon
# Out:
#    The Global Carbon Budget 2022 is a collaborative effort of the global carbon cycle science community coordinated by the Global Carbon Project.
# 0   DATA SOURCES & TERMS OF USE:\nThe use of data ...
# 1                                                 NaN
# 2   Reference of the full global carbon budget 202...
# 3                                                 NaN
# 4   Further information is available on: http://ww...
# 5   References to previous updates of the Global C...
# 6   2022a: Friedlingstein Pierre, Matthew W. Jones...
# 7   2020: Friedlingstein Pierre, Michael O’Sulliva...
# 8   2019: Friedlingstein Pierre, Matthew W. Jones,...
# 9   2018b: Le Quéré Corinne, Robbie M. Andrew, Pie...
# 10  2018a: Le Quéré, Corinne, Robbie M. Andrew, Pi...
# 11  2017: Peters, G.P., C. Le Quéré, R.M. Andrew, ...
# 12  2016: Le Quéré, C., Andrew, R. M., Canadell, J...
# 13  2015: Le Quéré, C, R Moriarty, RM Andrew, JG C...
# 14  2015: Jackson, R. B., Canadell, J. G., Le Quér...
# ...
