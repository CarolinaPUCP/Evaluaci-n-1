# %%
import pandas as pd
import numpy as np


# MIGRACION
df_migracion=pd.read_excel("DATA-MIGRACION.xls")

# COVID
df_covid=pd.read_csv("DATA-COVID-MUERTES.csv")

# CARBON
df_carbon=pd.read_excel("DATA-CARBON.xlsx")

# %%
# intercambiar columnas a filas y viceversa

# CARBON
df_carbon = df_carbon.T

# COVID
df_covid = df_covid.T

# %%
# mostrar colmumna de Migración neta en el 2021
df_migracion_2021=df_migracion.iloc[:,[0,65]]

# mostrar colmumna de muertes por covid en 2023 - 12 - octubre
df_covid_2023=df_covid.iloc[:,[1378]]

# guardar data solo de emisiones de CO2 en 2021
df_carbon_2021 = df_carbon.iloc[:,[0,6]]

# %%
# COVID
# Resetear el índice y convertirlo en una columna
df_covid_2023 = df_covid_2023.reset_index()

# %%
# MIGRACION
# eliminar filas 0,1,2 (fecha de actualizacion, NaN, Nombre de país)
chau_fila_m=[0,1,2]
df_migracion_2021 = df_migracion_2021.drop(index=chau_fila_m).copy()

# CARBON
# eliminar fila 0 (emision de CO2)
chau_fila_c=["Territorial emissions in MtCO₂"]
df_carbon_2021 = df_carbon_2021.drop(index=chau_fila_c).copy()

# COVID
# eliminar filas 0,1 (fecha, mundo data)
chau_fila_d=[0,1]
df_covid_2023 = df_covid_2023.drop(index=chau_fila_d).copy()

# %%
# MIGRACION
# cambiar nombre del indice "Data Source" a "Pais"
df_migracion_2021 = df_migracion_2021.rename(columns={ "Data Source" : 'Pais'})

# COVID
# cambiar nombre del indice "index" a "Pais"
df_covid_2023 = df_covid_2023.rename(columns={'index': 'Pais'})

# CARBON
# cambiar nombre del indice 0 a "Pais"
df_carbon_2021 = df_carbon_2021.rename(columns={ 0 : "Pais"})

# %%
# MIGRACION
# cambiar nombre del indice "Unnamed:66" a "Migracion_Neta_2021"
df_migracion_2021 = df_migracion_2021.rename(columns={ "Unnamed: 65" : "Migracion_Neta_2021"})

# COVID
# cambiar nombre del indice "1378" a 'Muertes_Covid_12_10_2023'
df_covid_2023 = df_covid_2023.rename(columns={ 1378 : 'Muertes_Covid_12_10_2023'})

# CARBON
# cambiar nombre del indice "Unnamed: 64" a "Territorial emissions in MTCO2"
df_carbon_2021 = df_carbon_2021.rename(columns={ 6 : "Territorial emissions in MTCO2"})

# %%
# borrar valores de NaN en Pais

# MIGRACION
df_migracion_2021 = df_migracion_2021.dropna(subset=['Pais'])

# COVID
df_covid_2023.dropna(subset=['Pais'])

# CARBON
df_carbon_2021 = df_carbon_2021.dropna(subset=['Pais'])

# %%
# MIGRACION
# borrar valores de NaN en Migracion_Neta_2021
df_migracion_2021 = df_migracion_2021.dropna(subset=['Migracion_Neta_2021'])

# COVID
# borrar valores de NaN en Muertes_Covid_12_10_2023
df_covid_2023.dropna(subset=['Muertes_Covid_12_10_2023'])

# CARBON
# borrar valores de NaN en Territorial emissions in MTCO2
df_carbon_2021 = df_carbon_2021.dropna(subset=['Territorial emissions in MTCO2'])

# %%
# volver todos los paises a tipo oracion

# MIGRACION
df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.title()

# COVID
df_covid_2023['Pais'] = df_covid_2023['Pais'].str.title()

# CARBON
df_carbon_2021['Pais'] = df_carbon_2021['Pais'].str.title()

# %%
# reemplazar " " con "_" en la data de Pais

# MIGRACION
df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.replace(' ', '_')

# COVID
df_covid_2023['Pais'] = df_covid_2023['Pais'].str.replace(' ', '_')

# CARBON
df_carbon_2021['Pais'] = df_carbon_2021['Pais'].str.replace(' ', '_')

# %%
# reemplazar tildes

# MIGRACION
df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.replace('á', 'a').str.replace('é', 'e').str.replace('í', 'i').str.replace('ó', 'o').str.replace('ú', 'u')
df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.replace('Á', 'A').str.replace('É', 'E').str.replace('Í', 'I').str.replace('Ó', 'O').str.replace('Ú', 'U')

# COVID
df_covid_2023['Pais'] = df_covid_2023['Pais'].str.replace('á', 'a').str.replace('é', 'e').str.replace('í', 'i').str.replace('ó', 'o').str.replace('ú', 'u')
df_covid_2023['Pais'] = df_covid_2023['Pais'].str.replace('Á', 'A').str.replace('É', 'E').str.replace('Í', 'I').str.replace('Ó', 'O').str.replace('Ú', 'U')

# CARBON
df_carbon_2021['Pais'] = df_carbon_2021['Pais'].str.replace('á', 'a').str.replace('é', 'e').str.replace('í', 'i').str.replace('ó', 'o').str.replace('ú', 'u')
df_carbon_2021['Pais'] = df_carbon_2021['Pais'].str.replace('Á', 'A').str.replace('É', 'E').str.replace('Í', 'I').str.replace('Ó', 'O').str.replace('Ú', 'U')

# %%
# Borra caracteres especiales de Pais menos "_"

# MIGRACION
df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.replace('[^a-zA-Z0-9_]', '', regex=True)

# COVID
df_covid_2023['Pais'] = df_covid_2023['Pais'].str.replace('[^a-zA-Z0-9_]', '', regex=True)

# CARBON
df_carbon_2021['Pais'] = df_carbon_2021['Pais'].str.replace('[^a-zA-Z0-9_]', '', regex=True)

# %%
# enumerar correctamente

# MIGRACION
df_migracion_2021.reset_index(drop=True,inplace=True)

# COVID
df_covid_2023.reset_index(drop=True,inplace=True)

# CARBON
df_carbon_2021.reset_index(drop=True,inplace=True)

# %%
################## ISOS

# %%
df_isos=pd.read_excel("DATA-ISOS.xlsx")
df_isos
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %%
# eliminar valores que se encuentran en parentesis

df_isos['Country'] = df_isos['Country'].str.replace(r'\(.*\)', '', regex=True)
df_isos
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           UZBEKISTAN                   The Republic of Uzbekistan
# 167             VIET NAM           The Socialist Republic of Viet Nam
# 168                YEMEN                        The Republic of Yemen
# 169               ZAMBIA                       The Republic of Zambia
# 170             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %%
# Convertir a estilo de oración
df_isos['Country'] = df_isos['Country'].str.title()
df_isos
# Out:
#                  Country                            Officialstatename  \
# 0            Afghanistan          The Islamic Republic of Afghanistan
# 1                Albania                      The Republic of Albania
# 2                Algeria  The People's Democratic Republic of Algeria
# 3                 Angola                       The Republic of Angola
# 4    Antigua And Barbuda                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           Uzbekistan                   The Republic of Uzbekistan
# 167             Viet Nam           The Socialist Republic of Viet Nam
# 168                Yemen                        The Republic of Yemen
# 169               Zambia                       The Republic of Zambia
# 170             Zimbabwe                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %%
# cambiar nombre del indice "Country" a "Pais"
df_isos = df_isos.rename(columns={ "Country" : 'Pais'})
df_isos
# Out:
#                     Pais                            Officialstatename  \
# 0            Afghanistan          The Islamic Republic of Afghanistan
# 1                Albania                      The Republic of Albania
# 2                Algeria  The People's Democratic Republic of Algeria
# 3                 Angola                       The Republic of Angola
# 4    Antigua And Barbuda                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           Uzbekistan                   The Republic of Uzbekistan
# 167             Viet Nam           The Socialist Republic of Viet Nam
# 168                Yemen                        The Republic of Yemen
# 169               Zambia                       The Republic of Zambia
# 170             Zimbabwe                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %%
# reemplazar " " con "_" en la data de Pais
df_isos['Pais'] = df_isos['Pais'].str.replace(' ', '_')

# %%
# reemplazar tildes
df_isos['Pais'] = df_isos['Pais'].str.replace('á', 'a').str.replace('é', 'e').str.replace('í', 'i').str.replace('ó', 'o').str.replace('ú', 'u')
df_isos['Pais'] = df_isos['Pais'].str.replace('Á', 'A').str.replace('É', 'E').str.replace('Í', 'I').str.replace('Ó', 'O').str.replace('Ú', 'U')

# %%
# Borra caracteres especiales de Pais menos "_"
df_isos['Pais'] = df_isos['Pais'].str.replace('[^a-zA-Z0-9_]', '', regex=True)

# %%
df_isos
# Out:
#                     Pais                            Officialstatename  \
# 0            Afghanistan          The Islamic Republic of Afghanistan
# 1                Albania                      The Republic of Albania
# 2                Algeria  The People's Democratic Republic of Algeria
# 3                 Angola                       The Republic of Angola
# 4    Antigua_And_Barbuda                          Antigua and Barbuda
# ..                   ...                                          ...
# 166           Uzbekistan                   The Republic of Uzbekistan
# 167             Viet_Nam           The Socialist Republic of Viet Nam
# 168                Yemen                        The Republic of Yemen
# 169               Zambia                       The Republic of Zambia
# 170             Zimbabwe                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .al   AL  ALB
# 2             .dz   DZ  DZA
# 3             .ao   AO  AGO
# 4             .ag   AG  ATG
# ..            ...  ...  ...
# 166           .uz   UZ  UZB
# 167           .vn   VN  VNM
# 168           .ye   YE  YEM
# 169           .zm   ZM  ZMB
# 170           .zw   ZW  ZWE
#
# [171 rows x 5 columns]

# %%
## fuzz

# %%
# MIGRACION
from thefuzz import process as fz

resta_m_covid = set(df_migracion_2021.Pais) - set(df_covid_2023.Pais)
resta_covid_m = set(df_covid_2023.Pais) - set(df_migracion_2021.Pais)

# coincidencias de restas
[(f,fz.extractOne(f, resta_m_covid)) for f in sorted(resta_covid_m)]
# Out:
# [('Afghanistan', ('Afganistan', 95)),
#  ('Africa', ('Africa_Al_Sur_Del_Sahara_Excluido_Altos_Ingresos', 90)),
#  ('Algeria', ('Argelia', 71)),
#  ('American_Samoa', ('America_Latina_Y_El_Caribe_Birf_Y_La_Aif', 64)),
#  ('Anguilla', ('Papua_Nueva_Guinea', 56)),
#  ('Antigua_And_Barbuda', ('Antigua_Y_Barbuda', 89)),
#  ('Asia', ('Asia_Meridional_Birf_Y_La_Aif', 90)),
#  ('Azerbaijan', ('Azerbaiyan', 90)),
#  ('Bahrain', ('Bahrein', 86)),
#  ('Belgium', ('Belgica', 71)),
#  ('Belize', ('Belice', 83)),
#  ('Bermuda', ('Bermudas', 93)),
#  ('Bonaire_Sint_Eustatius_And_Saba', ('Espaa', 54)),
#  ('Bosnia_And_Herzegovina', ('Bosnia_Y_Herzegovina', 90)),
#  ('Brazil', ('Brasil', 83)),
#  ('British_Virgin_Islands', ('Islandia', 72)),
#  ('Brunei', ('Brunei_Darussalam', 90)),
#  ('Cambodia', ('Camboya', 80)),
#  ('Cameroon', ('Camerun', 80)),
#  ('Cape_Verde', ('Cabo_Verde', 80)),
#  ('Cayman_Islands', ('Islandia', 72)),
#  ('Central_African_Republic', ('Mariana', 64)),
#  ('Comoros', ('Comoras', 86)),
#  ('Congo', ('Congo_Republica_Democratica_Del', 90)),
#  ('Cook_Islands', ('Islandia', 72)),
#  ('Cote_DIvoire', ('Cte_DIvoire', 96)),
#  ('Croatia', ('Croacia', 86)),
#  ('Cyprus', ('Chipre', 50)),
#  ('Czechia', ('Grecia', 62)),
#  ('Democratic_Republic_Of_Congo', ('Corea_Republica_De', 65)),
#  ('Denmark', ('Dinamarca', 62)),
#  ('Dominican_Republic', ('Corea_Republica_De', 61)),
#  ('Egypt', ('Egipto_Republica_Arabe_De', 72)),
#  ('Equatorial_Guinea', ('Papua_Nueva_Guinea', 57)),
#  ('Ethiopia', ('Etiopia', 93)),
#  ('Europe', ('Union_Europea', 90)),
#  ('European_Union', ('Reino_Unido', 64)),
#  ('Faeroe_Islands', ('Islandia', 72)),
#  ('Falkland_Islands', ('Islandia', 68)),
#  ('Finland', ('Finlandia', 88)),
#  ('France', ('Polinesia_Francesa', 90)),
#  ('French_Guiana', ('Francia', 60)),
#  ('French_Polynesia', ('Japon', 54)),
#  ('Germany', ('Granada', 57)),
#  ('Greece', ('Grecia', 67)),
#  ('Greenland', ('Groenlandia', 80)),
#  ('Grenada', ('Granada', 86)),
#  ('Guadeloupe', ('Sudan_Del_Sur', 52)),
#  ('Guernsey', ('Islas_Virgenes_EeUu', 56)),
#  ('High_Income', ('Paises_De_Ingreso_Mediano_Bajo', 50)),
#  ('Hungary', ('Hungria', 71)),
#  ('Iceland', ('Irlanda', 71)),
#  ('Iran', ('Iran_Republica_Islamica_Del', 90)),
#  ('Ireland', ('Irlanda', 86)),
#  ('Isle_Of_Man', ('Isla_De_Man', 73)),
#  ('Italy', ('Italia', 73)),
#  ('Japan', ('Japon', 80)),
#  ('Jersey', ('Cabo_Verde', 50)),
#  ('Jordan', ('Jordania', 86)),
#  ('Kazakhstan', ('Kazajstan', 84)),
#  ('Kyrgyzstan', ('Kirguistan', 70)),
#  ('Laos', ('Islas_Del_Canal', 68)),
#  ('Latvia', ('America_Latina_Y_El_Caribe_Birf_Y_La_Aif', 75)),
#  ('Lebanon', ('Libano', 77)),
#  ('Libya', ('Libia', 80)),
#  ('Lithuania', ('Lituania', 94)),
#  ('Low_Income', ('Europa_Y_Asia_Central_Excluido_Altos_Ingresos', 54)),
#  ('Lower_Middle_Income', ('America_Del_Norte', 50)),
#  ('Luxembourg', ('Luxemburgo', 90)),
#  ('Malaysia', ('Malasia', 93)),
#  ('Maldives', ('Maldivas', 88)),
#  ('Marshall_Islands', ('Islandia', 72)),
#  ('Martinique', ('Mariana', 59)),
#  ('Mauritius', ('Mauricio', 71)),
#  ('Mayotte', ('Oriente_Medio_Y_Norte_De_Africa_Birf_Y_La_Aif', 51)),
#  ('Micronesia_Country', ('Micronesia_Estados_Federados_De', 60)),
#  ('Moldova', ('Republica_De_Moldova', 90)),
#  ('Montserrat', ('Posterior_Al_Dividendo_Demografico', 54)),
#  ('Morocco', ('Mauricio', 53)),
#  ('Netherlands', ('Irlanda', 64)),
#  ('New_Caledonia', ('Nueva_Caledonia', 86)),
#  ('New_Zealand', ('Nueva_Zelandia', 72)),
#  ('Niue', ('Papua_Nueva_Guinea', 68)),
#  ('North_America', ('Samoa_Americana', 64)),
#  ('North_Korea', ('Oriente_Medio_Y_Norte_De_Africa_Birf_Y_La_Aif', 58)),
#  ('North_Macedonia', ('Letonia', 64)),
#  ('Northern_Mariana_Islands', ('Mariana', 90)),
#  ('Norway', ('Noruega', 62)),
#  ('Oceania', ('Ucrania', 71)),
#  ('Palestine', ('Tunez', 60)),
#  ('Papua_New_Guinea', ('Papua_Nueva_Guinea', 88)),
#  ('Philippines', ('Filipinas', 70)),
#  ('Pitcairn', ('Italia', 57)),
#  ('Poland', ('Polonia', 62)),
#  ('Reunion', ('Reino_Unido', 67)),
#  ('Romania', ('Rumania', 86)),
#  ('Russia', ('Federacion_De_Rusia', 75)),
#  ('Saint_Barthelemy', ('Bahrein', 51)),
#  ('Saint_Helena', ('Santa_Lucia', 61)),
#  ('Saint_Kitts_And_Nevis', ('Saint_Kitts_Y_Nevis', 90)),
#  ('Saint_Lucia', ('Santa_Lucia', 91)),
#  ('Saint_Martin_French_Part', ('Mariana', 64)),
#  ('Saint_Pierre_And_Miquelon', ('Sierra_Leona', 54)),
#  ('Saint_Vincent_And_The_Grenadines', ('San_Vicente_Y_Las_Granadinas', 70)),
#  ('Sao_Tome_And_Principe', ('Santo_Tome_Y_Principe', 86)),
#  ('Saudi_Arabia', ('Sudafrica', 67)),
#  ('Sierra_Leone', ('Sierra_Leona', 92)),
#  ('Singapore', ('Singapur', 82)),
#  ('Slovakia', ('Republica_Eslovaca', 72)),
#  ('Slovenia', ('Eslovenia', 94)),
#  ('Solomon_Islands', ('Islandia', 72)),
#  ('South_Africa', ('Sudafrica', 76)),
#  ('South_America', ('Samoa_Americana', 71)),
#  ('South_Korea', ('Noruega', 51)),
#  ('South_Sudan', ('Suiza', 54)),
#  ('Spain', ('Saint_Kitts_Y_Nevis', 72)),
#  ('Sweden', ('Paises_De_Ingreso_Bajo', 60)),
#  ('Switzerland', ('Irlanda', 69)),
#  ('Syria', ('Republica_Arabe_Siria', 72)),
#  ('Tajikistan', ('Tayikistan', 90)),
#  ('Thailand', ('Tailandia', 82)),
#  ('Timor', ('TimorLeste', 90)),
#  ('Tokelau', ('Groenlandia', 51)),
#  ('Trinidad_And_Tobago', ('Trinidad_Y_Tobago', 89)),
#  ('Tunisia', ('Lituania', 67)),
#  ('Turkey', ('Tunez', 55)),
#  ('Turks_And_Caicos_Islands', ('Islandia', 68)),
#  ('Ukraine', ('Fragiles_Y_Situaciones_De_Conflicto_Afectados', 64)),
#  ('United_Arab_Emirates', ('Republica_Arabe_Siria', 54)),
#  ('United_Kingdom', ('Mundo', 54)),
#  ('United_States', ('Region_Administrativa_Especial_De_Macao_China', 56)),
#  ('United_States_Virgin_Islands', ('Islandia', 68)),
#  ('Upper_Middle_Income', ('America_Del_Norte', 50)),
#  ('Vatican', ('Corea_Republica_Popular_Democratica_De', 64)),
#  ('Vietnam', ('Viet_Nam', 93)),
#  ('Wallis_And_Futuna', ('Libano', 60)),
#  ('Yemen', ('Yemen_Rep_Del', 90))]

# %%
# mantener mayores a 80%
df_resta1 = [(f,fz.extractOne(f, df_isos.Pais)) for f in sorted(df_migracion_2021.Pais)
 if fz.extractOne(f, df_isos.Pais)[1]>=80]

# %%
# Unir cambios
fragile2019.Country.replace(to_replace=changesFragile1,inplace=True)
# Out:
# [('Afganistan', ('Afghanistan', 95, 0)),
#  ('Albania', ('Albania', 100, 1)),
#  ('Alemania', ('Albania', 80, 1)),
#  ('Angola', ('Angola', 100, 3)),
#  ('Antigua_Y_Barbuda', ('Antigua_And_Barbuda', 89, 4)),
#  ('Argentina', ('Argentina', 100, 5)),
#  ('Armenia', ('Armenia', 100, 6)),
#  ('Australia', ('Australia', 100, 7)),
#  ('Austria', ('Austria', 100, 8)),
#  ('Azerbaiyan', ('Azerbaijan', 90, 9)),
#  ('Bahamas', ('Bahamas_', 93, 10)),
#  ('Bahrein', ('Bahrain', 86, 11)),
#  ('Bangladesh', ('Bangladesh', 100, 12)),
#  ('Barbados', ('Barbados', 100, 13)),
#  ('Belarus', ('Belarus', 100, 14)),
#  ('Belice', ('Belize', 83, 16)),
#  ('Benin', ('Benin', 100, 17)),
#  ('Bhutan', ('Bhutan', 100, 18)),
#  ('Bolivia', ('Bolivia_', 93, 19)),
#  ('Bosnia_Y_Herzegovina', ('Bosnia_And_Herzegovina', 90, 20)),
#  ('Botswana', ('Botswana', 100, 21)),
#  ('Brasil', ('Brazil', 83, 22)),
#  ('Brunei_Darussalam', ('Brunei_Darussalam', 100, 23)),
#  ('Bulgaria', ('Bulgaria', 100, 24)),
#  ('Burkina_Faso', ('Burkina_Faso', 100, 25)),
#  ('Burundi', ('Burundi', 100, 26)),
#  ('Cabo_Verde', ('Cabo_Verde', 100, 27)),
#  ('Camboya', ('Cambodia', 80, 28)),
#  ('Camerun', ('Cameroon', 80, 29)),
#  ('Canada', ('Canada', 100, 30)),
#  ('Chad', ('Chad', 100, 32)),
#  ('Chile', ('Chile', 100, 33)),
#  ('China', ('China', 100, 34)),
#  ('Colombia', ('Colombia', 100, 35)),
#  ('Comoras', ('Comoros_', 80, 36)),
#  ('Congo_Republica_Del', ('Congo_', 90, 37)),
#  ('Congo_Republica_Democratica_Del', ('Congo_', 90, 37)),
#  ('Costa_Rica', ('Costa_Rica', 100, 39)),
#  ('Croacia', ('Croatia', 86, 41)),
#  ('Cte_DIvoire', ('Cte_DIvoire', 100, 40)),
#  ('Cuba', ('Cuba', 100, 42)),
#  ('Djibouti', ('Djibouti', 100, 46)),
#  ('Dominica', ('Dominican_Republic_', 90, 47)),
#  ('Ecuador', ('Ecuador', 100, 48)),
#  ('El_Salvador', ('El_Salvador', 100, 50)),
#  ('Eslovenia', ('Slovenia', 94, 142)),
#  ('Estonia', ('Estonia', 100, 52)),
#  ('Eswatini', ('Eswatini', 100, 53)),
#  ('Etiopia', ('Ethiopia', 93, 54)),
#  ('Fiji', ('Fiji', 100, 55)),
#  ('Finlandia', ('Finland', 88, 56)),
#  ('Gabon', ('Gabon', 100, 58)),
#  ('Gambia', ('Gambia_', 92, 59)),
#  ('Georgia', ('Georgia', 100, 60)),
#  ('Ghana', ('Ghana', 100, 62)),
#  ('Granada', ('Grenada', 86, 64)),
#  ('Guatemala', ('Guatemala', 100, 65)),
#  ('Guinea', ('Guinea', 100, 66)),
#  ('GuineaBissau', ('GuineaBissau', 100, 67)),
#  ('Guinea_Ecuatorial', ('Guinea', 90, 66)),
#  ('Guyana', ('Guyana', 100, 68)),
#  ('Haiti', ('Haiti', 100, 69)),
#  ('Honduras', ('Honduras', 100, 70)),
#  ('India', ('India', 100, 73)),
#  ('Indonesia', ('Indonesia', 100, 74)),
#  ('Iran_Republica_Islamica_Del', ('Iran_', 90, 75)),
#  ('Iraq', ('Iraq', 100, 76)),
#  ('Irlanda', ('Ireland', 86, 77)),
#  ('Isla_De_San_Martin_Parte_Francesa', ('France', 90, 57)),
#  ('Jamaica', ('Jamaica', 100, 79)),
#  ('Japon', ('Japan', 80, 80)),
#  ('Jordania', ('Jordan', 86, 81)),
#  ('Kazajstan', ('Kazakhstan', 84, 82)),
#  ('Kenya', ('Kenya', 100, 83)),
#  ('Kuwait', ('Kuwait', 100, 85)),
#  ('Lesotho', ('Lesotho', 100, 90)),
#  ('Letonia', ('Estonia', 86, 52)),
#  ('Liberia', ('Liberia', 100, 91)),
#  ('Libia', ('Liberia', 83, 91)),
#  ('Lituania', ('Lithuania', 94, 93)),
#  ('Luxemburgo', ('Luxembourg', 90, 94)),
#  ('Madagascar', ('Madagascar', 100, 96)),
#  ('Malasia', ('Malaysia', 93, 98)),
#  ('Malawi', ('Malawi', 100, 97)),
#  ('Maldivas', ('Maldives', 88, 99)),
#  ('Mali', ('Mali', 100, 100)),
#  ('Malta', ('Malta', 100, 101)),
#  ('Mariana', ('Mauritania', 82, 102)),
#  ('Mauritania', ('Mauritania', 100, 102)),
#  ('Mexico', ('Mexico', 100, 104)),
#  ('Micronesia_Estados_Federados_De', ('Micronesia_', 90, 105)),
#  ('Mongolia', ('Mongolia', 100, 107)),
#  ('Montenegro', ('Montenegro', 100, 108)),
#  ('Mozambique', ('Mozambique', 100, 110)),
#  ('Myanmar', ('Myanmar', 100, 111)),
#  ('Namibia', ('Namibia', 100, 112)),
#  ('Nepal', ('Nepal', 100, 113)),
#  ('Nicaragua', ('Nicaragua', 100, 116)),
#  ('Niger', ('Niger_', 91, 117)),
#  ('Nigeria', ('Nigeria', 100, 118)),
#  ('Oman', ('Oman', 100, 120)),
#  ('Pakistan', ('Pakistan', 100, 121)),
#  ('Panama', ('Panama', 100, 122)),
#  ('Papua_Nueva_Guinea', ('Guinea', 90, 66)),
#  ('Paraguay', ('Paraguay', 100, 124)),
#  ('Peru', ('Peru', 100, 125)),
#  ('Polinesia_Francesa', ('France', 90, 57)),
#  ('Portugal', ('Portugal', 100, 128)),
#  ('Qatar', ('Qatar', 100, 129)),
#  ('Republica_De_Moldova', ('Moldova_', 84, 106)),
#  ('Rumania', ('Romania', 86, 130)),
#  ('Rwanda', ('Rwanda', 100, 132)),
#  ('Samoa', ('Samoa', 100, 133)),
#  ('Samoa_Americana', ('Samoa', 90, 133)),
#  ('Santo_Tome_Y_Principe', ('Sao_Tome_And_Principe', 86, 134)),
#  ('Senegal', ('Senegal', 100, 136)),
#  ('Serbia', ('Serbia', 100, 137)),
#  ('Seychelles', ('Seychelles', 100, 138)),
#  ('Sierra_Leona', ('Sierra_Leone', 92, 139)),
#  ('Singapur', ('Singapore', 82, 140)),
#  ('Somalia', ('Mali', 90, 100)),
#  ('Sri_Lanka', ('Sri_Lanka', 100, 146)),
#  ('Sudan', ('Sudan_', 91, 147)),
#  ('Sudan_Del_Sur', ('Sudan_', 90, 147)),
#  ('Suriname', ('Suriname', 100, 148)),
#  ('Tailandia', ('Thailand', 82, 153)),
#  ('Tanzania', ('Tanzania_The_United_Republic_Of', 90, 152)),
#  ('Tayikistan', ('Tajikistan', 90, 151)),
#  ('TimorLeste', ('TimorLeste', 100, 154)),
#  ('Togo', ('Togo', 100, 155)),
#  ('Trinidad_Y_Tobago', ('Trinidad_And_Tobago', 89, 156)),
#  ('Turkmenistan', ('Turkmenistan', 100, 159)),
#  ('Uganda', ('Uganda', 100, 160)),
#  ('Uruguay', ('Uruguay', 100, 165)),
#  ('Uzbekistan', ('Uzbekistan', 100, 166)),
#  ('Viet_Nam', ('Viet_Nam', 100, 167)),
#  ('Yemen_Rep_Del', ('Yemen', 90, 168)),
#  ('Zambia', ('Zambia', 100, 169)),
#  ('Zimbabwe', ('Zimbabwe', 100, 170))]

# %%
################## MERGE INTERSECCION

# %%
# MIGRACION
# df_migracion_2021

# COVID
# df_covid_2023

# CARBON
# df_carbon_2021

# ISOS
# df_isos

# %%
# Merge MIGRACION e ISOS

junta_i1 = df_isos.merge(df_migracion_2021)
junta_i1
# Out:
#           Pais                   Officialstatename InternetccTLD iso2 iso3  \
# 0      Albania             The Republic of Albania           .al   AL  ALB
# 1       Angola              The Republic of Angola           .ao   AO  AGO
# 2    Argentina              The Argentine Republic           .ar   AR  ARG
# 3      Armenia             The Republic of Armenia           .am   AM  ARM
# 4    Australia       The Commonwealth of Australia           .au   AU  AUS
# ..         ...                                 ...           ...  ...  ...
# 80     Uruguay    The Oriental Republic of Uruguay           .uy   UY  URY
# 81  Uzbekistan          The Republic of Uzbekistan           .uz   UZ  UZB
# 82    Viet_Nam  The Socialist Republic of Viet Nam           .vn   VN  VNM
# 83      Zambia              The Republic of Zambia           .zm   ZM  ZMB
# 84    Zimbabwe            The Republic of Zimbabwe           .zw   ZW  ZWE
#
#     Migracion_Neta_2021
# 0              -10612.0
# 1               29089.0
# 2                2344.0
# 3              -12825.0
# 4              117929.0
# ..                  ...
# 80              -1486.0
# 81             -39201.0
# 82               -992.0
# 83               9015.0
# 84             -25005.0
#
# [85 rows x 6 columns]

# %%
# Merge junta1 y CARBON

junta_i2 = junta_i1.merge(df_carbon_2021)
junta_i2
# Out:
#           Pais                 Officialstatename InternetccTLD iso2 iso3  \
# 0      Albania           The Republic of Albania           .al   AL  ALB
# 1       Angola            The Republic of Angola           .ao   AO  AGO
# 2    Argentina            The Argentine Republic           .ar   AR  ARG
# 3      Armenia           The Republic of Armenia           .am   AM  ARM
# 4    Australia     The Commonwealth of Australia           .au   AU  AUS
# ..         ...                               ...           ...  ...  ...
# 77      Uganda            The Republic of Uganda           .ug   UG  UGA
# 78     Uruguay  The Oriental Republic of Uruguay           .uy   UY  URY
# 79  Uzbekistan        The Republic of Uzbekistan           .uz   UZ  UZB
# 80      Zambia            The Republic of Zambia           .zm   ZM  ZMB
# 81    Zimbabwe          The Republic of Zimbabwe           .zw   ZW  ZWE
#
#     Migracion_Neta_2021 Territorial emissions in MTCO2
# 0              -10612.0                         4.6191
# 1               29089.0                        21.3627
# 2                2344.0                       186.4483
# 3              -12825.0                          6.806
# 4              117929.0                       391.1874
# ..                  ...                            ...
# 77              43465.0                         5.7805
# 78              -1486.0                         6.7379
# 79             -39201.0                       121.6315
# 80               9015.0                         7.6762
# 81             -25005.0                        11.2961
#
# [82 rows x 7 columns]

# %%
# Merge junta2 y COVID

junta_if = junta_i2.merge(df_covid_2023)
junta_if
# Out:
#           Pais                 Officialstatename InternetccTLD iso2 iso3  \
# 0      Albania           The Republic of Albania           .al   AL  ALB
# 1       Angola            The Republic of Angola           .ao   AO  AGO
# 2    Argentina            The Argentine Republic           .ar   AR  ARG
# 3      Armenia           The Republic of Armenia           .am   AM  ARM
# 4    Australia     The Commonwealth of Australia           .au   AU  AUS
# ..         ...                               ...           ...  ...  ...
# 74      Uganda            The Republic of Uganda           .ug   UG  UGA
# 75     Uruguay  The Oriental Republic of Uruguay           .uy   UY  URY
# 76  Uzbekistan        The Republic of Uzbekistan           .uz   UZ  UZB
# 77      Zambia            The Republic of Zambia           .zm   ZM  ZMB
# 78    Zimbabwe          The Republic of Zimbabwe           .zw   ZW  ZWE
#
#     Migracion_Neta_2021 Territorial emissions in MTCO2  \
# 0              -10612.0                         4.6191
# 1               29089.0                        21.3627
# 2                2344.0                       186.4483
# 3              -12825.0                          6.806
# 4              117929.0                       391.1874
# ..                  ...                            ...
# 74              43465.0                         5.7805
# 75              -1486.0                         6.7379
# 76             -39201.0                       121.6315
# 77               9015.0                         7.6762
# 78             -25005.0                        11.2961
#
#    Muertes_Covid_12_10_2023
# 0                    3604.0
# 1                    1936.0
# 2                  130472.0
# 3                    8751.0
# 4                   23188.0
# ..                      ...
# 74                   3632.0
# 75                   7634.0
# 76                   1016.0
# 77                   4069.0
# 78                   5718.0
#
# [79 rows x 8 columns]
