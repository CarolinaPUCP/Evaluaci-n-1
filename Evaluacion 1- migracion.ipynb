# %%
import pandas as pd

df_migracion=pd.read_excel("DATA-MIGRACION.xls")

df_migracion

# listo
# Out:
#            Data Source Indicadores del desarrollo mundial      Unnamed: 2  \
# 0    Last Updated Date                2023-09-19 00:00:00             NaN
# 1                  NaN                                NaN             NaN
# 2         Country Name                       Country Code  Indicator Name
# 3                Aruba                                ABW  Migración neta
# 4                  NaN                                AFE  Migración neta
# ..                 ...                                ...             ...
# 264             Kosovo                                XKX  Migración neta
# 265    Yemen, Rep. del                                YEM  Migración neta
# 266          Sudáfrica                                ZAF  Migración neta
# 267             Zambia                                ZMB  Migración neta
# 268           Zimbabwe                                ZWE  Migración neta
#
#          Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0               NaN         NaN         NaN         NaN         NaN
# 1               NaN         NaN         NaN         NaN         NaN
# 2    Indicator Code      1960.0      1961.0      1962.0      1963.0
# 3       SM.POP.NETM         0.0      -569.0      -609.0      -646.0
# 4       SM.POP.NETM    -90849.0     -1348.0    -24259.0    -16266.0
# ..              ...         ...         ...         ...         ...
# 264     SM.POP.NETM     -6603.0     -6713.0     -7466.0     -7874.0
# 265     SM.POP.NETM    -17145.0    -17494.0    -17846.0    -18217.0
# 266     SM.POP.NETM     18909.0     56098.0     68068.0     70976.0
# 267     SM.POP.NETM     -3894.0     -4357.0     -4756.0     -5029.0
# 268     SM.POP.NETM     -8256.0     -8582.0     -8931.0     -9369.0
#
#      Unnamed: 8  Unnamed: 9  ...  Unnamed: 57  Unnamed: 58  Unnamed: 59  \
# 0           NaN         NaN  ...          NaN          NaN          NaN
# 1           NaN         NaN  ...          NaN          NaN          NaN
# 2        1964.0      1965.0  ...       2013.0       2014.0       2015.0
# 3        -684.0      -726.0  ...        134.0         88.0        177.0
# 4       37452.0     11041.0  ...     -92842.0    -199608.0     394925.0
# ..          ...         ...  ...          ...          ...          ...
# 264     -8266.0     -8573.0  ...     -40468.0     -56637.0     -14819.0
# 265    -18583.0    -18968.0  ...     -23747.0     -30048.0     -38355.0
# 266     74419.0     80687.0  ...      63794.0     290874.0     644996.0
# 267     -5214.0     -5370.0  ...      15574.0      16580.0      16283.0
# 268    -10064.0    -10889.0  ...     -59918.0     -59918.0     -59918.0
#
#      Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63  Unnamed: 64  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2         2016.0       2017.0       2018.0       2019.0       2020.0
# 3          170.0        218.0        367.0        412.0          0.0
# 4      -864708.0    -343075.0    -366105.0    -187410.0     -48955.0
# ..           ...          ...          ...          ...          ...
# 264     -31383.0     -33495.0     -34137.0     -33469.0     -15050.0
# 265     -39688.0     -39672.0     -39699.0     -39769.0     -86100.0
# 266    -866101.0     -10681.0      27265.0      22728.0      30852.0
# 267      17285.0      20268.0      18019.0      18019.0       9015.0
# 268     -59918.0     -59918.0     -59918.0     -59918.0     -29955.0
#
#      Unnamed: 65  Unnamed: 66
# 0            NaN          NaN
# 1            NaN          NaN
# 2         2021.0       2022.0
# 3          501.0          NaN
# 4      -179444.0          NaN
# ..           ...          ...
# 264     -15050.0          NaN
# 265    -101468.0          NaN
# 266      10934.0          NaN
# 267       9015.0          NaN
# 268     -25005.0          NaN
#
# [269 rows x 67 columns]

# %%
# mostrar colmumna de Migración neta en el 2021

df_migracion_2021=df_migracion.iloc[:,[0,65]]

df_migracion_2021

# LISTO
# Out:
#            Data Source  Unnamed: 65
# 0    Last Updated Date          NaN
# 1                  NaN          NaN
# 2         Country Name       2021.0
# 3                Aruba        501.0
# 4                  NaN    -179444.0
# ..                 ...          ...
# 264             Kosovo     -15050.0
# 265    Yemen, Rep. del    -101468.0
# 266          Sudáfrica      10934.0
# 267             Zambia       9015.0
# 268           Zimbabwe     -25005.0
#
# [269 rows x 2 columns]

# %%
# eliminar filas 0,1,2 (fecha de actualizacion, NaN, Nombre de país)

chau_filas=[0,1,2]

df_migracion_2021 = df_migracion_2021.drop(index=chau_filas)

# LISTO

# %%
# mostrar data

df_migracion_2021

# listo
# Out:
#          Data Source  Unnamed: 65
# 3              Aruba        501.0
# 4                NaN    -179444.0
# 5         Afganistán    -183672.0
# 6                NaN    -264802.0
# 7             Angola      29089.0
# ..               ...          ...
# 264           Kosovo     -15050.0
# 265  Yemen, Rep. del    -101468.0
# 266        Sudáfrica      10934.0
# 267           Zambia       9015.0
# 268         Zimbabwe     -25005.0
#
# [266 rows x 2 columns]

# %%
# cambiar nombre del indice "Data Source" a "Pais"

df_migracion_2021 = df_migracion_2021.rename(columns={ "Data Source" : 'Pais'})

df_migracion_2021

# listo
# Out:
#                 Pais  Unnamed: 65
# 3              Aruba        501.0
# 4                NaN    -179444.0
# 5         Afganistán    -183672.0
# 6                NaN    -264802.0
# 7             Angola      29089.0
# ..               ...          ...
# 264           Kosovo     -15050.0
# 265  Yemen, Rep. del    -101468.0
# 266        Sudáfrica      10934.0
# 267           Zambia       9015.0
# 268         Zimbabwe     -25005.0
#
# [266 rows x 2 columns]

# %%
# cambiar nombre del indice "Unnamed:66" a "Migracion_Neta_2021"

df_migracion_2021 = df_migracion_2021.rename(columns={ "Unnamed: 65" : "Migracion_Neta_2021"})

df_migracion_2021

# LISTO
# Out:
#                 Pais  Migracion_Neta_2021
# 3              Aruba                501.0
# 4                NaN            -179444.0
# 5         Afganistán            -183672.0
# 6                NaN            -264802.0
# 7             Angola              29089.0
# ..               ...                  ...
# 264           Kosovo             -15050.0
# 265  Yemen, Rep. del            -101468.0
# 266        Sudáfrica              10934.0
# 267           Zambia               9015.0
# 268         Zimbabwe             -25005.0
#
# [266 rows x 2 columns]

# %%
# borrar valores de NaN en Pais

df_migracion_2021 = df_migracion_2021.dropna(subset=['Pais'])
# listo

# %%
# borrar valores de NaN en Migracion_Neta_2021

df_migracion_2021 = df_migracion_2021.dropna(subset=['Migracion_Neta_2021'])
# lsti

# %%
# reemplazar " " con "_" en la data de Pais

df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.replace(' ', '_')

df_migracion_2021

# listo
# Out:
#                 Pais  Migracion_Neta_2021
# 3              Aruba                501.0
# 5         Afganistán            -183672.0
# 7             Angola              29089.0
# 8            Albania             -10612.0
# 9            Andorra               1377.0
# ..               ...                  ...
# 264           Kosovo             -15050.0
# 265  Yemen,_Rep._del            -101468.0
# 266        Sudáfrica              10934.0
# 267           Zambia               9015.0
# 268         Zimbabwe             -25005.0
#
# [263 rows x 2 columns]

# %%
# reemplazar tildes

df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.replace('á', 'a').str.replace('é', 'e').str.replace('í', 'i').str.replace('ó', 'o').str.replace('ú', 'u')
df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.replace('Á', 'A').str.replace('É', 'E').str.replace('Í', 'I').str.replace('Ó', 'O').str.replace('Ú', 'U')

df_migracion_2021

# listo
# Out:
#                 Pais  Migracion_Neta_2021
# 3              Aruba                501.0
# 5         Afganistan            -183672.0
# 7             Angola              29089.0
# 8            Albania             -10612.0
# 9            Andorra               1377.0
# ..               ...                  ...
# 264           Kosovo             -15050.0
# 265  Yemen,_Rep._del            -101468.0
# 266        Sudafrica              10934.0
# 267           Zambia               9015.0
# 268         Zimbabwe             -25005.0
#
# [263 rows x 2 columns]

# %%
# Borra caracteres especiales de Pais menos "_"

df_migracion_2021['Pais'] = df_migracion_2021['Pais'].str.replace('[^a-zA-Z0-9_]', '', regex=True)

df_migracion_2021

# listo
# Out:
#               Pais  Migracion_Neta_2021
# 3            Aruba                501.0
# 5       Afganistan            -183672.0
# 7           Angola              29089.0
# 8          Albania             -10612.0
# 9          Andorra               1377.0
# ..             ...                  ...
# 264         Kosovo             -15050.0
# 265  Yemen_Rep_del            -101468.0
# 266      Sudafrica              10934.0
# 267         Zambia               9015.0
# 268       Zimbabwe             -25005.0
#
# [263 rows x 2 columns]

# %%
# enumerar correctamente

df_migracion_2021.reset_index(drop=True,inplace=True)

df_migracion_2021

# listo
# Out:
#               Pais  Migracion_Neta_2021
# 0            Aruba                501.0
# 1       Afganistan            -183672.0
# 2           Angola              29089.0
# 3          Albania             -10612.0
# 4          Andorra               1377.0
# ..             ...                  ...
# 258         Kosovo             -15050.0
# 259  Yemen_Rep_del            -101468.0
# 260      Sudafrica              10934.0
# 261         Zambia               9015.0
# 262       Zimbabwe             -25005.0
#
# [263 rows x 2 columns]
