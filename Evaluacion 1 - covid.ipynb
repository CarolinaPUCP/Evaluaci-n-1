# %%
import pandas as pd
df_covid=pd.read_csv("DATA-COVID-MUERTE.csv")

df_covid
# Out:
#             date      World  Afghanistan    Africa  Albania  Algeria  \
# 0     2020-01-03        NaN          NaN       NaN      NaN      NaN
# 1     2020-01-04        NaN          NaN       NaN      NaN      NaN
# 2     2020-01-05        3.0          NaN       NaN      NaN      NaN
# 3     2020-01-06        3.0          NaN       NaN      NaN      NaN
# 4     2020-01-07        3.0          NaN       NaN      NaN      NaN
# ...          ...        ...          ...       ...      ...      ...
# 1374  2023-10-08  6961001.0       7950.0  259021.0   3604.0   6881.0
# 1375  2023-10-09  6961001.0       7950.0  259021.0   3604.0   6881.0
# 1376  2023-10-10  6961001.0       7950.0  259021.0   3604.0   6881.0
# 1377  2023-10-11  6961001.0       7950.0  259021.0   3604.0   6881.0
# 1378  2023-10-12  6961001.0       7950.0  259021.0   3604.0   6881.0
#
#       American Samoa  Andorra  Angola  Anguilla  ...  Uruguay  Uzbekistan  \
# ...

# %%
# intercambiar columnas a filas y viceversa

df_covid = df_covid.T

df_covid
# Out:
#                          0           1           2           3           4     \
# date               2020-01-03  2020-01-04  2020-01-05  2020-01-06  2020-01-07
# World                     NaN         NaN         3.0         3.0         3.0
# Afghanistan               NaN         NaN         NaN         NaN         NaN
# Africa                    NaN         NaN         NaN         NaN         NaN
# Albania                   NaN         NaN         NaN         NaN         NaN
# ...                       ...         ...         ...         ...         ...
# Vietnam                   NaN         NaN         NaN         NaN         NaN
# Wallis and Futuna         NaN         NaN         NaN         NaN         NaN
# Yemen                     NaN         NaN         NaN         NaN         NaN
# Zambia                    NaN         NaN         NaN         NaN         NaN
# Zimbabwe                  NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
# mostrar colmumna de muertes por covid en 2023 - 12 - octubre

df_covid_2023=df_covid.iloc[:,[0,1378]]

df_covid_2023
# Out:
#                          0           1378
# date               2020-01-03  2023-10-12
# World                     NaN   6961001.0
# Afghanistan               NaN      7950.0
# Africa                    NaN    259021.0
# Albania                   NaN      3604.0
# ...                       ...         ...
# Vietnam                   NaN     43206.0
# Wallis and Futuna         NaN         8.0
# Yemen                     NaN      2159.0
# Zambia                    NaN      4069.0
# Zimbabwe                  NaN      5718.0
#
# [247 rows x 2 columns]

# %%
# eliminar filas 0,1 (fecha, total mundo)

chau_filas=[0,1]

df_covid_2023.drop(index=chau_filas, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       1 # eliminar filas 0,1 (fecha, total mundo)
#       3 chau_filas=[0,1]
# ----> 5 df_covid_2023.drop(index=chau_filas, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
# ...

# %%
df_covid_2023
# Out:
#                   1378
# 0
# 2020-01-03  2023-10-12
# NaN          6961001.0
# NaN             7950.0
# NaN           259021.0
# NaN             3604.0
# ...                ...
# NaN            43206.0
# NaN                8.0
# NaN             2159.0
# NaN             4069.0
# NaN             5718.0
#
# [247 rows x 1 columns]

# %%
# Out:
#            0           1378
# 0    2020-01-03  2023-10-12
# 1           NaN   6961001.0
# 2           NaN      7950.0
# 3           NaN    259021.0
# 4           NaN      3604.0
# ..          ...         ...
# 242         NaN     43206.0
# 243         NaN         8.0
# 244         NaN      2159.0
# 245         NaN      4069.0
# 246         NaN      5718.0
#
# [247 rows x 2 columns]

# %%
# Out:
# None

# %%
import pandas as pd

# Crear un DataFrame de ejemplo
data = {'Nombre': ['Alice', 'Bob', 'Charlie'],
        'Edad': [25, 30, 35]}
indices = ['fila1', 'fila2', 'fila3']  # Nombres de los índices
df = pd.DataFrame(data, index=indices)

# Resetear el índice y convertirlo en una columna
df_con_indices_como_columna = df.reset_index()

# Mostrar el DataFrame con los índices como una columna
print(df_con_indices_como_columna)
# Out:
#    index   Nombre  Edad
# 0  fila1    Alice    25
# 1  fila2      Bob    30
# 2  fila3  Charlie    35
