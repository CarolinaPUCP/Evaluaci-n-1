# %%
import pandas as pd
df_covid=pd.read_csv("DATA-COVID")

df_covid
# Out:
#             Country  Year  Daily new confirmed cases of COVID-19  \
# 0       Afghanistan   -18                                    0.0
# 1       Afghanistan   -17                                    0.0
# 2       Afghanistan   -16                                    0.0
# 3       Afghanistan   -15                                    0.0
# 4       Afghanistan   -14                                    0.0
# ...             ...   ...                                    ...
# 344745     Zimbabwe  1356                                    0.0
# 344746     Zimbabwe  1357                                    0.0
# 344747     Zimbabwe  1358                                    0.0
# 344748     Zimbabwe  1359                                    0.0
# 344749     Zimbabwe  1360                                    0.0
#
#         Daily new confirmed deaths due to COVID-19  \
# 0                                              0.0
# 1                                              0.0
# ...

# %%
# mostrar data solo alemania

df_alemania=df_covid.loc[df_covid['Country'] == 'Germany']

df_alemania
# Out:
#         Country  Year  Daily new confirmed cases of COVID-19  \
# 113078  Germany   -18                                    0.0
# 113079  Germany   -17                                    1.0
# 113080  Germany   -16                                    0.0
# 113081  Germany   -15                                    0.0
# 113082  Germany   -14                                    0.0
# ...         ...   ...                                    ...
# 114452  Germany  1356                                    0.0
# 114453  Germany  1357                                    0.0
# 114454  Germany  1358                                    0.0
# 114455  Germany  1359                                    0.0
# 114456  Germany  1360                                    0.0
#
#         Daily new confirmed deaths due to COVID-19  \
# 113078                                         0.0
# 113079                                         0.0
# 113080                                         3.0
# ...
