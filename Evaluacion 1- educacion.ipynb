# %%
import pandas as pd
df_educacion=pd.read_excel("DATA-EDUCACION.xls")

df_educacion
# Out:
#            Data Source Indicadores del desarrollo mundial  \
# 0    Last Updated Date                2023-09-19 00:00:00
# 1                  NaN                                NaN
# 2         Country Name                       Country Code
# 3                Aruba                                ABW
# 4                  NaN                                AFE
# ..                 ...                                ...
# 264             Kosovo                                XKX
# 265    Yemen, Rep. del                                YEM
# 266          Sudáfrica                                ZAF
# 267             Zambia                                ZMB
# 268           Zimbabwe                                ZWE
#
#                                             Unnamed: 2         Unnamed: 3  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# ...

# %%
# guardar data solo de Tasa de finalización de la educación de nivel primario, mujeres en 2020

df_educacion_2020=df_educacion.iloc[:,[0,66]]

df_educacion_2020
# Out:
#            Data Source  Unnamed: 66
# 0    Last Updated Date          NaN
# 1                  NaN          NaN
# 2         Country Name       2022.0
# 3                Aruba          NaN
# 4                  NaN          NaN
# ..                 ...          ...
# 264             Kosovo          NaN
# 265    Yemen, Rep. del          NaN
# 266          Sudáfrica          NaN
# 267             Zambia          NaN
# 268           Zimbabwe          NaN
#
# [269 rows x 2 columns]

# %%
# eliminar filas 0,1,2 (fecha de actualizacion, NaN, Nombre de país)

chau_filas=[0,1,2]

df_educacion_2020.drop(index=chau_filas, inplace=True)
# Out:
# C:\Users\cpauc\AppData\Local\Temp\ipykernel_5604\3816046361.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_educacion_2020.drop(index=chau_filas, inplace=True)

# %%
# mostrar data de nuevo

df_educacion_2020
# Out:
#          Data Source  Unnamed: 66
# 3              Aruba          NaN
# 4                NaN          NaN
# 5         Afganistán          NaN
# 6                NaN          NaN
# 7             Angola          NaN
# ..               ...          ...
# 264           Kosovo          NaN
# 265  Yemen, Rep. del          NaN
# 266        Sudáfrica          NaN
# 267           Zambia          NaN
# 268         Zimbabwe          NaN
#
# [266 rows x 2 columns]

# %%
# enumerar correctamente

df_educacion_2020.reset_index(drop=True,inplace=True)

# %%
# mostrar data

df_educacion_2020
# Out:
#          Data Source  Unnamed: 66
# 0              Aruba          NaN
# 1                NaN          NaN
# 2         Afganistán          NaN
# 3                NaN          NaN
# 4             Angola          NaN
# ..               ...          ...
# 261           Kosovo          NaN
# 262  Yemen, Rep. del          NaN
# 263        Sudáfrica          NaN
# 264           Zambia          NaN
# 265         Zimbabwe          NaN
#
# [266 rows x 2 columns]

# %%
# cambiar nombre del indice "Unnamed: 66" a "Educacion_F_2020"

df_educacion_2020 = df_educacion_2020.rename(columns={ "Unnamed: 66" : "Educacion_F_2020"})

df_educacion_2020
# Out:
#          Data Source  Educacion_F_2020
# 0              Aruba               NaN
# 1                NaN               NaN
# 2         Afganistán               NaN
# 3                NaN               NaN
# 4             Angola               NaN
# ..               ...               ...
# 261           Kosovo               NaN
# 262  Yemen, Rep. del               NaN
# 263        Sudáfrica               NaN
# 264           Zambia               NaN
# 265         Zimbabwe               NaN
#
# [266 rows x 2 columns]

# %%
# cambiar nombre del indice "Data Source" a "Pais"

df_educacion_2020 = df_educacion_2020.rename(columns={ "Data Source" : "Pais"})

df_educacion_2020
# Out:
#                 Pais  Educacion_F_2020
# 0              Aruba               NaN
# 1                NaN               NaN
# 2         Afganistán               NaN
# 3                NaN               NaN
# 4             Angola               NaN
# ..               ...               ...
# 261           Kosovo               NaN
# 262  Yemen, Rep. del               NaN
# 263        Sudáfrica               NaN
# 264           Zambia               NaN
# 265         Zimbabwe               NaN
#
# [266 rows x 2 columns]
